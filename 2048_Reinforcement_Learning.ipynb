# %% [markdown]
# # 2048 Game using Deep Reinforcement Learning
#
# 2048 is a popular sliding puzzle game back in 2014, with the goal of obtaining a tile of 2048 with combining smaller tiles that are also power of 2's, for example 2,4,8,...,1024.
#
# ![](https://upload.wikimedia.org/wikipedia/commons/6/64/2048_Screenshot.png)

# %% [markdown]
# # Part 1: Create a 2048 Game
# A playable 2048 game with the appropriate logic and behaviour in python code.
#
# Reference: https://flothesof.github.io/2048-game.html.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from numpy import zeros, array, rot90
import random
import matplotlib.pyplot as plt
import math

# %%
class Board():
    def __init__(self):
        self.board = zeros((4, 4), dtype=int)
        self.fill_cell()
        self.game_over = False
        self.total_score = 0

    def reset(self):
        self.__init__()

    # Adding a random 2/4 into the board
    def fill_cell(self):
      i, j = (self.board == 0).nonzero()
      if i.size != 0:
          rnd = random.randint(0, i.size - 1)
          self.board[i[rnd], j[rnd]] = 2 * ((random.random() > .9) + 1)

    # Moving tiles in a column to left and merge if possible
    def move_left(self, col):
      new_col = zeros((4), dtype=col.dtype)
      j = 0
      previous = None
      for i in range(col.size):
          if col[i] != 0: # number different from zero
              if previous == None:
                  previous = col[i]
              else:
                  if previous == col[i]:
                      new_col[j] = 2 * col[i]
                      self.total_score += new_col[j]
                      j += 1
                      previous = None
                  else:
                      new_col[j] = previous
                      j += 1
                      previous = col[i]
      if previous != None:
          new_col[j] = previous
      return new_col

    def move(self, direction):
      # 0: left, 1: up, 2: right, 3: down
      rotated_board = rot90(self.board, direction)
      cols = [rotated_board[i, :] for i in range(4)]
      new_board = array([self.move_left(col) for col in cols])
      return rot90(new_board, -direction)

    def is_game_over(self):
      for i in range(self.board.shape[0]):
        for j in range(self.board.shape[1]):
          if self.board[i][j] == 0:
            return False
          if i != 0 and self.board[i - 1][j] == self.board[i][j]:
            return False
          if j != 0 and self.board[i][j - 1] == self.board[i][j]:
            return False
      return True


    def step(self, direction):
      new_board = self.move(direction)
      if not (new_board == self.board).all():
        self.board = new_board
        self.fill_cell()

# %%
def main_loop(b, direction):
    new_board = b.move(direction)
    moved = False
    if (new_board == b.board).all():
        # move is invalid
        pass
    else:
        moved = True
        b.board = new_board
        b.fill_cell()
    return moved

# %%
# Sample Game (Manual) (Skip this cell if you dont want to try the game manually)
game = Board()
finish = False
while not finish:
  direction = int(input("please enter a direction: (0) Left, (1) Up, (2) Right, (3) Down"))
  if direction < 0 or direction > 3:
    print("Not a valid input! Please enter a valid value (0/1/2/3)!")
    continue
  moved = main_loop(game, direction)
  if not moved:
    print("Not a valid move! Nothing has changed.")
    continue
  print(game.board)
  print(game.total_score)
  finish = game.is_game_over()
print("Game Over!, Total Score is {}".format(game.total_score))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-8cbc82957dae> in <cell line: 4>()
#       3 finish = False
#       4 while not finish:
# ----> 5   direction = int(input("please enter a direction: (0) Left, (1) Up, (2) Right, (3) Down"))
#       6   if direction < 0 or direction > 3:
#       7     print("Not a valid input! Please enter a valid value (0/1/2/3)!")
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# # Part 2: Baseline Result
# A naive strategy with choosing the next move randomly as the baseline experiment.

# %%
def sample_game_random():
  game = Board()
  finish = False
  while not finish:
    direction = np.random.randint(4)
    moved = main_loop(game, direction)
    if not moved:
      # Sample another direction if the move is invalid
      continue
    finish = game.is_game_over()
  total_score = game.total_score
  best_tile = game.board.max()
  return total_score, best_tile

# %%
scores_random, best_tiles_random = [], []
for i in range(1000):
  if i % 100 == 0:
    print(f"Iteration {i}")
  total_score, best_tile = sample_game_random()
  scores_random.append(total_score)
  best_tiles_random.append(best_tile)
print("Finish")
# Out:
# Iteration 0
# Iteration 100
# Iteration 200
# Iteration 300
# Iteration 400
# Iteration 500
# Iteration 600
# Iteration 700
# Iteration 800
# Iteration 900
# Finish

# %%
# Plot best score distribution
plt.hist(scores_random, bins = 50)
plt.title("Total score distribution")
plt.xlabel("Total Score")
plt.ylabel("Frequency")
plt.show()

# %%
# Plot best score distribution
max_power = int(math.log(max(best_tiles_random), 2)) + 1
min_power = int(math.log(min(best_tiles_random), 2))
unique, counts = np.unique(best_tiles_random, return_counts=True)
plt.bar([str(2 ** i) for i in range(min_power, max_power)], counts)
plt.title("Best tile distribution")
plt.xlabel("Best tile")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# It seems that random move is not a good stretagy. Probably computer can learn how to choose the next move more intelligently...

# %% [markdown]
# # Part 3: Reinforcement Learning With Deep Q-Learning

# %% [markdown]
# ## State
# The number of states in this model are $16^{16}$, since there are 4 * 4 = 16 grids in the game, and each game could take the value of 0, 2, $2^2=4$, $2^3=8$, ... , $2^{15} = 32768$.
#
# Given the huge number of states, it is infeasible to use dynamic programming algorithm (e.g. SARSA / Q-Learning) to calculate $Q(s,a)$. Therefore approximating Q-value with deep neural network is required.
#
# To represent the state of this model, a (4, 4, 16) dimensional numpy array is used, where first dimension represents row, second dimension represents column and third dimension represents the one-hot encoding of the value of the tile at that position. For example if 2 is in the top-left corner, then index [0, 0, 1] would be 1, and other entries in [0, 0, :] are 0.

# %% [markdown]
# ## Reward
# The reward for each action is defined as follows: For each merge in the move, the reward is the sum of the tiles after merging. For example, if [4, 4, 2, 2] is moved to left, it becomes [8, 4, 0, 0], with total score of 8 + 4 = 12 for that step.

# %% [markdown]
# ## Q Learning Update
# Below is the algorithm for Q-Learning, with $s_t$ being the current state, $a_t$ the current action, $r_t$ current reward and $s_{t+1}$ next state. These values are also stored in the memory as part of memory buffer.
# <div>
# <img src="https://i.imgur.com/Ccrvg7G.jpeg" width="500"/>
# </div>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T
from collections import namedtuple, deque
from itertools import count

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def encode_state(board):
  board_flat = [0 if e == 0 else int(math.log(e, 2)) for e in board.flatten()]
  board_flat = torch.LongTensor(board_flat)
  board_flat = F.one_hot(board_flat, num_classes=16).float().flatten()
  board_flat = board_flat.reshape(1, 4, 4, 16).permute(0, 3, 1, 2)
  return board_flat

# %%
def decode_state(encoded_state):
    reshaped_state = encoded_state.permute(0, 2, 3, 1)
    board_flat = reshaped_state.argmax(dim=3)
    board_decoded = torch.pow(2, board_flat.float())
    board_decoded = torch.where(board_flat == 0, torch.tensor(0.0), board_decoded)

    # Create a Board object with the decoded board
    board = Board()
    board.board = board_decoded.numpy()[0].astype('int')

    return board

# %%
# Defining the replay buffer
Transition = namedtuple('Transition',
                        ('state', 'action', 'next_state', 'reward'))

class ReplayMemory(object):
    def __init__(self, capacity):
        self.memory = deque([],maxlen=capacity)

    def push(self, *args):
        self.memory.append(Transition(*args))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %%
class ConvBlock(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(ConvBlock, self).__init__()
        d = output_dim // 4
        self.conv1 = nn.Conv2d(input_dim, d, 1, padding='same')
        self.conv2 = nn.Conv2d(input_dim, d, 2, padding='same')
        self.conv3 = nn.Conv2d(input_dim, d, 3, padding='same')
        self.conv4 = nn.Conv2d(input_dim, d, 4, padding='same')

    def forward(self, x):
        x = x.to(device)
        output1 = self.conv1(x)
        output2 = self.conv2(x)
        output3 = self.conv3(x)
        output4 = self.conv4(x)
        return torch.cat((output1, output2, output3, output4), dim=1)

class DQN(nn.Module):

    def __init__(self):
        super(DQN, self).__init__()
        self.conv1 = ConvBlock(16, 2048)
        self.conv2 = ConvBlock(2048, 2048)
        self.conv3 = ConvBlock(2048, 2048)
        self.dense1 = nn.Linear(2048 * 16, 1024)
        self.dense6 = nn.Linear(1024, 4)

    def forward(self, x):
        x = x.to(device)
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = nn.Flatten()(x)
        x = F.dropout(self.dense1(x))
        return self.dense6(x)

# %%
import math
import copy
import random

class Node:
    def __init__(self, board, parent=None, move=None):
        self.board = board
        self.parent = parent
        self.children = []
        self.visits = 0
        self.score = 0
        self.move = move

    def select_child(self, c_param=1.4):
        log_n_parent = math.log(self.visits) if self.visits > 0 else 0
        best_score = -float('inf')
        best_child = None

        for child in self.children:
            exploit = child.score / child.visits if child.visits > 0 else 0
            explore = c_param * math.sqrt(log_n_parent / child.visits) if child.visits > 0 else float('inf')
            score = exploit + explore

            if score > best_score:
                best_score = score
                best_child = child

        return best_child

    def expand(self):
        directions = [0, 1, 2, 3]  # left, up, right, down
        random.shuffle(directions)

        for direction in directions:
            new_board = copy.deepcopy(self.board)
            if main_loop(new_board, direction):
                new_node = Node(new_board, parent=self, move=direction)
                self.children.append(new_node)

    def backpropagate(self, score):
        self.visits += 1
        self.score += score

        if self.parent:
            self.parent.backpropagate(score)

def monte_carlo_tree_search(board, num_iterations=1000):
    root = Node(board)

    for _ in range(num_iterations):
        node = root
        board_copy = copy.deepcopy(board)

        # Selection
        while node.children:
            node = node.select_child()
            board_copy = node.board

        # Expansion
        if not board_copy.is_game_over():
            node.expand()

        # Simulation
        leaf_node = node.select_child() if node.children else node
        leaf_board = leaf_node.board
        while not leaf_board.is_game_over():
            directions = [0, 1, 2, 3]
            random.shuffle(directions)
            for direction in directions:
                if main_loop(leaf_board, direction):
                    leaf_board.fill_cell()
                    break

        # Backpropagation
        score = leaf_board.total_score
        leaf_node.backpropagate(score)

    # Select the best child of the root node
    best_child = max(root.children, key=lambda node: node.visits)
    return best_child.move

# Example usage
# board = Board()
# while not board.is_game_over():
#     best_move = monte_carlo_tree_search(board)
#     board.step(best_move)
#     print("Current board:")
#     print(board.board)
#     print("Total score:", board.total_score)
#     print("Game over?", board.is_game_over())

# %%
# Neural Network Initialisation and utilities
BATCH_SIZE = 64
GAMMA = 0.99
EPS_START = 0.9
EPS_END = 0.01
EPS_DECAY = 0.9999
TARGET_UPDATE = 20
n_actions = 4

policy_net = DQN().to(device)
target_net = DQN().to(device)
# target_net.load_state_dict(policy_net.state_dict())
policy_net.load_state_dict(torch.load('/content/drive/MyDrive/2048_reinforcement_learning/policy_net.pth'))
target_net.load_state_dict(torch.load('/content/drive/MyDrive/2048_reinforcement_learning/target_net.pth'))
target_net.eval()
policy_net.train()

optimizer = optim.Adam(policy_net.parameters(), lr=5e-5)
# scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.98)
memory = ReplayMemory(50000)

steps_done = 0

num_rand = 0

def select_action(state):
    global steps_done, num_rand
    sample = random.random()
    eps_threshold = max(EPS_END, EPS_START * (EPS_DECAY ** steps_done))
    steps_done += 1
    if sample > eps_threshold:
        with torch.no_grad():
            return policy_net(state).max(1)[1].view(1, 1)
    else:
        print('.', end="")
        num_rand += 1
        mcts_move = monte_carlo_tree_search(decode_state(state))
        return torch.tensor([[mcts_move]], device=device, dtype=torch.long)

# %%
def optimize_model():
    if len(memory) < BATCH_SIZE:
        return
    transitions = memory.sample(BATCH_SIZE)
    batch = Transition(*zip(*transitions))

    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                          batch.next_state)), device=device, dtype=torch.bool)
    non_final_next_states = torch.cat([s for s in batch.next_state
                                                if s is not None])
    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    state_action_values = policy_net(state_batch).gather(1, action_batch)

    next_state_values = torch.zeros(BATCH_SIZE, device=device)
    next_state_values[non_final_mask] = target_net(non_final_next_states).max(1)[0].detach()
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    criterion = nn.MSELoss()
    loss = criterion(state_action_values, expected_state_action_values.unsqueeze(1))

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    # global steps_done
    # if steps_done % 5000 == 0 and steps_done < 1000000:
    #   print("Learning rate changed.")
    #   scheduler.step()

# %%
def same_move(state, next_state, last_memory):
  return torch.eq(state, last_memory.state).all() and torch.eq(next_state, last_memory.next_state).all()

# %%
game = Board()
total_scores, best_tile_list = [], []

num_episodes = 5000
for i_episode in range(num_episodes):
    print(f"Episode {i_episode}")
    game.reset()
    state = encode_state(game.board).float()
    duplicate = False
    non_valid_count, valid_count = 0, 0
    for t in count():
        # Select and perform an action
        action = select_action(state)
        old_score = game.total_score
        old_max = game.board.max()
        game.step(action.item())

        done = game.is_game_over()

        reward = (game.total_score - old_score)
        reward = torch.tensor([reward], device=device)

        # Observe new state
        if not done:
            next_state = encode_state(game.board).float()
        else:
            next_state = None

        if next_state != None and torch.eq(state, next_state).all():
          non_valid_count += 1
          reward -= 10
        else:
          valid_count += 1

        # Store the transition in memory
        # if next_state != None and duplicate and not torch.eq(state, next_state).all():
        #   duplicate = False

        # if not duplicate:
        if next_state == None or len(memory) == 0 or not same_move(state, next_state, memory.memory[-1]):
          memory.push(state, action, next_state, reward)

        # if next_state != None:
        #   duplicate = torch.eq(state, next_state).all()

        # Move to the next state
        state = next_state

        # Perform one step of the optimization (on the policy network)
        # optimize_model()

        if done:
          for _ in range(100):
            optimize_model()

          print(game.board)
          print(f"Episode Score: {game.total_score}")
          print(f"Non valid move count: {non_valid_count}")
          print(f"Valid move count: {valid_count}")
          total_scores.append(game.total_score)
          best_tile_list.append(game.board.max())
          if i_episode > 50:
            average = sum(total_scores[-50:]) / 50
            print(f"50 episode running average: {average}")
          break

    # Update the target network, copying all weights and biases in DQN
    if i_episode % TARGET_UPDATE == 0:
        target_net.load_state_dict(policy_net.state_dict())
        policy_net.train()

    if i_episode % 100 == 0:
        torch.save(policy_net.state_dict(), '/content/drive/MyDrive/2048_reinforcement_learning/policy_net.pth')
        torch.save(target_net.state_dict(), '/content/drive/MyDrive/2048_reinforcement_learning/target_net.pth')

print('Complete')
# Out:
# Episode 0
# .......................................................................................................................................................................................................................................................................................................................................................................................................................................[[  2   8 512   2]
#  [  4 128   2   8]
#  [ 32 256  64   4]
#  [  4  32   4   2]]
# Episode Score: 7060
# Non valid move count: 3
# Valid move count: 476
# Episode 1
# ..........................................................................................................................................................................................................................................................................................................................................................[[  2   4   2   4]
#  [  4  32  64   2]
#  [  8 512 128  16]
#  [  4  64   8   4]]
# Episode Score: 5588
# Non valid move count: 1
# Valid move count: 392
# Episode 2
# .......................................................................................................................................................................................................................................................................................................................[[  2   4   8   4]
#  [  8  16  32   8]
#  [512  64 128  16]
#  [  2   4  16   4]]
# Episode Score: 5364
# Non valid move count: 7
# Valid move count: 374
# Episode 3
# ..............................................................................................................................................................................................................................................................................................................................................................[[  8   2   8   4]
#  [ 16 512  16   8]
#  [  8  64 256   4]
#  [  4   2   8  16]]
# Episode Score: 6276
# Non valid move count: 11
# Valid move count: 425
# Episode 4
# ...........................................................................................................................................................................................[[  4  16   2   4]
#  [  2  32 128   8]
#  [  4  64 256   2]
#  [  2   4   8  32]]
# Episode Score: 3112
# Non valid move count: 1
# Valid move count: 253
# Episode 5
# ............................................................................................................................................................................................................[[  2   8  16   2]
#  [  4  64 128  32]
#  [ 32 256  32   2]
#  [  2   4   2   4]]
# Episode Score: 3260
# Non valid move count: 6
# Valid move count: 274
# Episode 6
# ........................................................................................................................................................................................[[  4  64   2   8]
#  [  8  16 128   4]
#  [ 16 256   8  32]
#  [  4  16   4   2]]
# Episode Score: 3120
# Non valid move count: 4
# Valid move count: 261
# Episode 7
# ..........................................................................................................................................................................[[  2   4   2   8]
#  [  4   2  16   2]
#  [ 32   4 128  64]
#  [  2 256   4   2]]
# Episode Score: 2972
# Non valid move count: 4
# Valid move count: 236
# Episode 8
# ................................................................................................................................................................................................................................................................................[[  2  32   4   2]
#  [  8 128  16   8]
#  [512  16  64  32]
#  [  4   8   4   2]]
# Episode Score: 5484
# Non valid move count: 11
# Valid move count: 392
# Episode 9
# ..........................................................................................................[[  4   8   4   2]
#  [ 32  16 128   8]
#  [  4  32   8  64]
#  [  8   4  16   4]]
# Episode Score: 1464
# Non valid move count: 3
# Valid move count: 155
# Episode 10
# .......................................................................................................................................................................[[  4  64   8   2]
#  [  8 128  16   8]
#  [ 16  64   8 256]
#  [  2   4  16   4]]
# Episode Score: 3292
# Non valid move count: 9
# Valid move count: 271
# Episode 11
# ....................................................................................................................................................................[[  2   4  16   4]
#  [ 16   8  64 256]
#  [  4 128   8  32]
#  [  2   8  16   4]]
# Episode Score: 3132
# Non valid move count: 2
# Valid move count: 264
# Episode 12
# ..................................................................................................................................................................................................................................................................................[[  2  32   4   2]
#  [  4   8 512   4]
#  [  8 256  32   2]
#  [  2   8  16   8]]
# Episode Score: 6144
# Non valid move count: 13
# Valid move count: 418
# Episode 13
# ...................................................................................................................................................................................................................................................[[  2   4  32   2]
#  [  8 128 512   4]
#  [  4  64  32   8]
#  [  2   8  16  64]]
# Episode Score: 5700
# Non valid move count: 18
# Valid move count: 402
# Episode 14
# ...............................................................................................................................................[[  8  32   4   2]
#  [  2   8 256   4]
#  [ 16  32  16 128]
#  [  4   8   4   8]]
# Episode Score: 2888
# Non valid move count: 7
# Valid move count: 239
# Episode 15
# .............................................................................................................................................................................................................................................................[[  4   2   4   2]
#  [  8  64  32   4]
#  [256 512   8   2]
#  [  2   8  64   4]]
# Episode Score: 6528
# Non valid move count: 12
# Valid move count: 439
# Episode 16
# .....................................................................................................................[[  4   2   8   4]
#  [  2 256   4   8]
#  [ 32  64  32   2]
#  [  4   8   2  16]]
# Episode Score: 2400
# Non valid move count: 2
# Valid move count: 203
# Episode 17
# ................................................................................................................................................[[  4  16   2   4]
#  [256 128   8   2]
#  [  8  64  32   8]
#  [  2  16  64   2]]
# Episode Score: 3396
# Non valid move count: 11
# Valid move count: 286
# Episode 18
# ............................................................................................................................................................................[[  2   4   2   4]
#  [ 64   8  16   8]
#  [  2  16 512   4]
#  [  4   2   4  16]]
# Episode Score: 4496
# Non valid move count: 7
# Valid move count: 304
# Episode 19
# ..........................................................................................................................[[  2   8 128   2]
#  [  8  16  64  16]
#  [  4 256  32   8]
#  [  2  32   4   2]]
# Episode Score: 3228
# Non valid move count: 5
# Valid move count: 276
# Episode 20
# ....................................................................................................[[  4   2   8   4]
#  [ 32   8  32   8]
#  [  4 256  64   2]
#  [  2   8   2   4]]
# Episode Score: 2368
# Non valid move count: 5
# Valid move count: 199
# Episode 21
# ..............................................................................................................................[[  4  16   4   2]
#  [  8   2   8   4]
#  [  4  16 256   8]
#  [  8  64   8 128]]
# Episode Score: 2976
# Non valid move count: 3
# Valid move count: 245
# Episode 22
# ..................................................................................................................[[  4   2   4   2]
#  [ 16  32 256   8]
#  [  4 128  64  16]
#  [  2  16  32   2]]
# Episode Score: 3184
# Non valid move count: 6
# Valid move count: 262
# Episode 23
# .............................................................................................................................................................................................[[  2  32   8   4]
#  [  8  64 512  32]
#  [  4  16 256   8]
#  [  2  32   4   2]]
# Episode Score: 6504
# Non valid move count: 29
# Valid move count: 443
# Episode 24
# .........................................................................................................[[  2   8   4   2]
#  [  4  32   2 256]
#  [  8  16   8   4]
#  [  4 128  32   2]]
# Episode Score: 2844
# Non valid move count: 5
# Valid move count: 234
# Episode 25
# .........................................................................................................................................................[[  2   4   2   4]
#  [ 16  32   8   2]
#  [ 64 512 128  16]
#  [ 16   2   4   2]]
# Episode Score: 5312
# Non valid move count: 12
# Valid move count: 363
# Episode 26
# ..........................................................................................[[  2   8   2   4]
#  [  4  32   8  16]
#  [  8 256 128   4]
#  [  4   8  64   2]]
# Episode Score: 3028
# Non valid move count: 7
# Valid move count: 247
# Episode 27
# .......................................................................................................................................................................................................[[  4 256   4   2]
#  [ 32 128  32   8]
#  [  8  16  64  16]
#  [  4 512   4   2]]
# Episode Score: 7140
# Non valid move count: 38
# Valid move count: 486
# Episode 28
# ..............................................................................................[[  4   8  16   4]
#  [ 16  64 128  16]
#  [  4 256  64  32]
#  [  2   8  16   2]]
# Episode Score: 3448
# Non valid move count: 25
# Valid move count: 290
# Episode 29
# .........................................................................................................................................[[  2   4  64   2]
#  [ 32 512   2   8]
#  [  2   8 128  32]
#  [  4   2   8   4]]
# Episode Score: 5340
# Non valid move count: 19
# Valid move count: 366
# Episode 30
# ...................................................................................................[[  4   2   4   2]
#  [  2  16  64   8]
#  [ 16 128 256  32]
#  [  2  16   4   2]]
# Episode Score: 3072
# Non valid move count: 54
# Valid move count: 251
# Episode 31
# ..........................................................................................................[[  2   4   8  32]
#  [  4  32 128   2]
#  [ 64 256   8  16]
#  [  2   4  16   8]]
# Episode Score: 3188
# Non valid move count: 20
# Valid move count: 266
# Episode 32
# ..............................................[[  8   2   4   2]
#  [ 32  64   8   4]
#  [  4   8 128  16]
#  [  2  32   8   2]]
# Episode Score: 1412
# Non valid move count: 6
# Valid move count: 147
# Episode 33
# .......................................................................[[  2   8  64   4]
#  [ 32  16 128  16]
#  [  4  64  32   8]
#  [  2   8  16   2]]
# Episode Score: 1764
# Non valid move count: 28
# Valid move count: 177
# Episode 34
# ...................................................................................................................................................[[  2   4  32   4]
#  [  8  64 256  16]
#  [  2  16  32   4]
#  [  4   2   4 512]]
# Episode Score: 6432
# Non valid move count: 38
# Valid move count: 439
# Episode 35
# .....................................................................................................................................................................................................................................................[[   4    8    4    2]
#  [   8   32 1024  128]
#  [   4   64   32    8]
#  [   2   16  256    4]]
# Episode Score: 12176
# Non valid move count: 77
# Valid move count: 725
# Episode 36
# ......................................................................................................[[  8 128   4   2]
#  [  2   8  32  64]
#  [  8  16 256  16]
#  [  2 128   2   4]]
# Episode Score: 3828
# Non valid move count: 30
# Valid move count: 314
# Episode 37
# ................................................................................................................[[  2 512   4  32]
#  [ 32   8  32   4]
#  [  4  64   2 128]
#  [  2   4   8   2]]
# Episode Score: 5500
# Non valid move count: 53
# Valid move count: 390
# Episode 38
# ....................[[ 8 16  8  2]
#  [16 64 16  8]
#  [ 4  2  8  4]
#  [ 2  8  4  2]]
# Episode Score: 508
# Non valid move count: 2
# Valid move count: 73
# Episode 39
# .................................................................................................................[[  2   8   2  16]
#  [ 16 256  32   4]
#  [  4  32 512 128]
#  [  2   4  16   4]]
# Episode Score: 6896
# Non valid move count: 74
# Valid move count: 470
# Episode 40
# .........................................................................[[  4 256   2   4]
#  [  2  16 128  32]
#  [ 64   8  64   4]
#  [  4  16   8   2]]
# Episode Score: 3328
# Non valid move count: 30
# Valid move count: 270
# Episode 41
# ....................................................................................................................[[  2 256   4  16]
#  [  4 512   2  32]
#  [  2  16  32  64]
#  [  4  64   8   2]]
# Episode Score: 6716
# Non valid move count: 52
# Valid move count: 461
# Episode 42
# ...........................................................[[  8   2   8   4]
#  [  4   8  32   8]
#  [ 16 128  64   4]
#  [  4   8 256   2]]
# Episode Score: 3052
# Non valid move count: 33
# Valid move count: 252
# Episode 43
# ...................................................................[[  2   8   4   2]
#  [  4  64  16   4]
#  [256  32   8  32]
#  [ 16   8 128   4]]
# Episode Score: 3176
# Non valid move count: 26
# Valid move count: 263
# Episode 44
# ....................................[[  2   4   8   4]
#  [ 16  32  16   2]
#  [  2 128  64   4]
#  [  8   4  16   8]]
# Episode Score: 1372
# Non valid move count: 19
# Valid move count: 145
# Episode 45
# ................................................................[[  8   2  32   2]
#  [  4   8  64   8]
#  [ 32 256  32  16]
#  [  4 128   8   4]]
# Episode Score: 3248
# Non valid move count: 95
# Valid move count: 268
# Episode 46
# ................................................[[  8   2  64   8]
#  [  2   4   2  32]
#  [  4   8  32   2]
#  [  2 128   8 256]]
# Episode Score: 3084
# Non valid move count: 29
# Valid move count: 249
# Episode 47
# ....................................................[[  8   4   2   8]
#  [  4 256  16   2]
#  [ 16  32 128  16]
#  [  8   4  64   4]]
# Episode Score: 3112
# Non valid move count: 25
# Valid move count: 259
# Episode 48
# ..................................................[[  2   8  16   4]
#  [  8 256  64  32]
#  [  4  32 128   4]
#  [  2   8   2   8]]
# Episode Score: 3140
# Non valid move count: 46
# Valid move count: 258
# Episode 49
# ............................................[[  2   8  16   8]
#  [ 16 128  32   4]
#  [  4   8  64  16]
#  [  2  16 128   4]]
# Episode Score: 2132
# Non valid move count: 21
# Valid move count: 201
# Episode 50
# ...............................................[[  2   4  16   2]
#  [ 16 128  64   8]
#  [ 64  32  16   2]
#  [  2   8 256   8]]
# Episode Score: 3412
# Non valid move count: 43
# Valid move count: 285
# Episode 51
# .....................................................[[  2   8  16   4]
#  [  4 256   8  16]
#  [ 32  16  64   2]
#  [  4 256   2   4]]
# Episode Score: 4080
# Non valid move count: 24
# Valid move count: 310
# 50 episode running average: 3980.56
# Episode 52
# ................................................................................[[  4   8   4   2]
#  [  8 512  16   4]
#  [ 32 256  64  32]
#  [  2   8  32   8]]
# Episode Score: 6564
# Non valid move count: 82
# Valid move count: 457
# 50 episode running average: 4004.56
# Episode 53
# .............................................................[[ 16   4 128   4]
#  [  8  16   4  32]
#  [  4 512   8   4]
#  [  2   4   2  64]]
# Episode Score: 5340
# Non valid move count: 42
# Valid move count: 374
# 50 episode running average: 3985.84
# Episode 54
# ...............................................................[[  4  16   4   2]
#  [ 16   8 512  16]
#  [ 32 128  32   4]
#  [  2   4   8   2]]
# Episode Score: 5164
# Non valid move count: 98
# Valid move count: 357
# 50 episode running average: 4026.88
# Episode 55
# .................................[[  2  16 256   8]
#  [  8   4  32   4]
#  [  4  16 128  16]
#  [  2   8   2   8]]
# Episode Score: 2800
# Non valid move count: 4
# Valid move count: 229
# 50 episode running average: 4017.68
# Episode 56
# ............................[[  2   4   8 128]
#  [  4   8   2   4]
#  [  2 128  32  64]
#  [  8   2   8   2]]
# Episode Score: 1980
# Non valid move count: 10
# Valid move count: 182
# 50 episode running average: 3994.88
# Episode 57
# ...............................................[[  2  16   4   2]
#  [  4   8  64   8]
#  [  8  16   4  32]
#  [  2 512   2   4]]
# Episode Score: 4560
# Non valid move count: 21
# Valid move count: 307
# 50 episode running average: 4026.64
# Episode 58
# .................................................[[  4   2   4   8]
#  [  2   4 128   4]
#  [  8 256  32  16]
#  [  2   8  64   4]]
# Episode Score: 3020
# Non valid move count: 39
# Valid move count: 246
# 50 episode running average: 3977.36
# Episode 59
# ....................................[[  4   8   2   4]
#  [  8  32  64  16]
#  [ 32  16   8   4]
#  [  4 128 256   2]]
# Episode Score: 3192
# Non valid move count: 15
# Valid move count: 267
# 50 episode running average: 4011.92
# Episode 60
# ..........................................[[  2   4   8  64]
#  [256   8 128   4]
#  [  4  16  64  16]
#  [  2  32   2   4]]
# Episode Score: 3364
# Non valid move count: 47
# Valid move count: 279
# 50 episode running average: 4013.36
# Episode 61
# .......................................................[[  4  16   2   4]
#  [ 16 512  32  16]
#  [  4  16 128   4]
#  [  2   4   8   2]]
# Episode Score: 5044
# Non valid move count: 63
# Valid move count: 340
# 50 episode running average: 4051.6
# Episode 62
# ....................................[[  2   4   8   4]
#  [  8  16 128  16]
#  [256  64  16   8]
#  [  2   8  32   2]]
# Episode Score: 3136
# Non valid move count: 23
# Valid move count: 264
# 50 episode running average: 3991.44
# Episode 63
# ..................[[  2   4  16   8]
#  [  4  32  64  32]
#  [  8 128  16   4]
#  [  4  64   8   2]]
# Episode Score: 1752
# Non valid move count: 14
# Valid move count: 179
# 50 episode running average: 3912.48
# Episode 64
# ......................................................[[  2  16 512   2]
#  [ 16   4  64   4]
#  [  8   2   4   2]
#  [  2 256   2   4]]
# Episode Score: 6188
# Non valid move count: 71
# Valid move count: 412
# 50 episode running average: 3978.48
# Episode 65
# ....................[[  4   8  16   8]
#  [ 16  64  32   2]
#  [  4   2  16 256]
#  [  2  16   8   2]]
# Episode Score: 2392
# Non valid move count: 14
# Valid move count: 203
# 50 episode running average: 3895.76
# Episode 66
# .............................[[ 64   2   4   2]
#  [  2   8  16  32]
#  [128  64 256   8]
#  [  4   2   8   4]]
# Episode Score: 3332
# Non valid move count: 70
# Valid move count: 275
# 50 episode running average: 3914.4
# Episode 67
# .................[[  2   4 128   2]
#  [  4   8  32   4]
#  [ 64  32   2   8]
#  [  4   8 128   4]]
# Episode Score: 2104
# Non valid move count: 38
# Valid move count: 197
# 50 episode running average: 3888.56
# Episode 68
# .................[[  2   8   4   2]
#  [  4   2  32   8]
#  [  8 256  16  64]
#  [  2  16   2   4]]
# Episode Score: 2304
# Non valid move count: 4
# Valid move count: 191
# 50 episode running average: 3844.72
# Episode 69
# ....................................[[  4   8   4   2]
#  [  8  64 128   8]
#  [ 16 256  32  16]
#  [  8  64   2   8]]
# Episode Score: 3388
# Non valid move count: 105
# Valid move count: 282
# 50 episode running average: 3847.92
# Episode 70
# ...........................[[  2  32   2  16]
#  [  4 128   4   2]
#  [ 32 256   8   4]
#  [  2   4  64   2]]
# Episode Score: 3092
# Non valid move count: 86
# Valid move count: 249
# 50 episode running average: 3862.4
# Episode 71
# ...................[[  2 256   2   4]
#  [  8   2   8   2]
#  [ 16   8 128   4]
#  [  2   4   2   8]]
# Episode Score: 2616
# Non valid move count: 62
# Valid move count: 210
# 50 episode running average: 3855.2
# Episode 72
# .....................................[[  4  16   4   2]
#  [  8 128  64  16]
#  [  4  16   4   2]
#  [  2 512   2   4]]
# Episode Score: 5180
# Non valid move count: 51
# Valid move count: 347
# 50 episode running average: 3895.12
# Episode 73
# ...............................[[  2   4   2  16]
#  [  4   2 128   4]
#  [  8 256  32 512]
#  [  2   4   8   2]]
# Episode Score: 6672
# Non valid move count: 111
# Valid move count: 440
# 50 episode running average: 3898.48
# Episode 74
# .......................[[  8  16   2   4]
#  [  2  32   8  64]
#  [  4 128  32   8]
#  [  8  16   2 256]]
# Episode Score: 3184
# Non valid move count: 95
# Valid move count: 264
# 50 episode running average: 3905.28
# Episode 75
# ....................[[  2   4  16   8]
#  [  4   8 256 128]
#  [128   4  16   4]
#  [  4   8   4   2]]
# Episode Score: 3376
# Non valid move count: 17
# Valid move count: 267
# 50 episode running average: 3866.56
# Episode 76
# ..............................[[  2  32   2   4]
#  [  8 512   8   2]
#  [ 16   2 128  64]
#  [  2   4  16   4]]
# Episode Score: 5280
# Non valid move count: 67
# Valid move count: 359
# 50 episode running average: 3911.6
# Episode 77
# ....[[16  2  4  2]
#  [ 4 32  8  4]
#  [ 8 16 64  2]
#  [ 4  8  2  4]]
# Episode Score: 580
# Non valid move count: 13
# Valid move count: 81
# 50 episode running average: 3780.4
# Episode 78
# ...............[[  2   4  64   8]
#  [  8   2  16   2]
#  [  2 128   8 128]
#  [  4  32   4   2]]
# Episode Score: 2028
# Non valid move count: 18
# Valid move count: 190
# 50 episode running average: 3752.0
# Episode 79
# ...................[[  4   8   4   8]
#  [ 16  32   8   4]
#  [  4  64 256  16]
#  [  2  16 128   4]]
# Episode Score: 3112
# Non valid move count: 40
# Valid move count: 259
# 50 episode running average: 3707.44
# Episode 80
# .......[[  2  16   2   8]
#  [  4 128   4   2]
#  [  8  16 128   8]
#  [  4   8   2   4]]
# Episode Score: 1652
# Non valid move count: 23
# Valid move count: 156
# 50 episode running average: 3679.04
# Episode 81
# ..........................[[  4   8   2   8]
#  [ 16 512   4 128]
#  [  2 128  16   2]
#  [  8   4   2   4]]
# Episode Score: 5660
# Non valid move count: 21
# Valid move count: 390
# 50 episode running average: 3728.48
# Episode 82
# .......................................................[[  2 256   8   2]
#  [  4  64  16 128]
#  [ 16  32   8  16]
#  [  4 512   4   2]]
# Episode Score: 7108
# Non valid move count: 218
# Valid move count: 490
# 50 episode running average: 3842.4
# Episode 83
# .......................[[  2   8  32   2]
#  [128   4 256   4]
#  [  8  16  32   8]
#  [  2   4   8   4]]
# Episode Score: 2844
# Non valid move count: 101
# Valid move count: 233
# 50 episode running average: 3864.0
# Episode 84
# ...................[[ 32   2   8   4]
#  [  2 128  32   2]
#  [256  32  64  16]
#  [  4   8  16   2]]
# Episode Score: 3272
# Non valid move count: 26
# Valid move count: 271
# 50 episode running average: 3800.8
# Episode 85
# .........[[  4   8   4   2]
#  [ 32  16  64   8]
#  [ 16   8   4   2]
#  [  2   4 128   8]]
# Episode Score: 1332
# Non valid move count: 18
# Valid move count: 139
# 50 episode running average: 3583.92
# Episode 86
# ...............[[  2   4  64  16]
#  [ 16   8  32 128]
#  [  2 256   4  16]
#  [  4   2   8   4]]
# Episode Score: 3104
# Non valid move count: 26
# Valid move count: 258
# 50 episode running average: 3569.44
# Episode 87
# ................[[  2  16   8   4]
#  [  8 128  32  16]
#  [  2 256  16   8]
#  [ 64   2   8   4]]
# Episode Score: 3116
# Non valid move count: 107
# Valid move count: 259
# 50 episode running average: 3521.76
# Episode 88
# ..............[[  8   2  32   4]
#  [  4  16   2  16]
#  [256 128  32   8]
#  [  8  16   4   2]]
# Episode Score: 2916
# Non valid move count: 41
# Valid move count: 242
# 50 episode running average: 3569.92
# Episode 89
# .................[[  2   8   4   2]
#  [256  16   8   4]
#  [  8 128  32  16]
#  [  4  16   4   2]]
# Episode Score: 2828
# Non valid move count: 198
# Valid move count: 237
# 50 episode running average: 3488.56
# Episode 90
# ........................[[ 16   4   2   4]
#  [  4 128 256   2]
#  [  8  32 128   4]
#  [ 64   8   4   2]]
# Episode Score: 3800
# Non valid move count: 95
# Valid move count: 313
# 50 episode running average: 3498.0
# Episode 91
# ....................[[  2  32   4   2]
#  [  4 128  16   8]
#  [512   8  32   4]
#  [  4   2  16   2]]
# Episode Score: 5120
# Non valid move count: 71
# Valid move count: 351
# 50 episode running average: 3466.08
# Episode 92
# .............[[  2   4   2   4]
#  [  4  32   8   2]
#  [ 16   8  32   4]
#  [ 32 256   8   2]]
# Episode Score: 2224
# Non valid move count: 79
# Valid move count: 191
# 50 episode running average: 3449.52
# Episode 93
# .........................[[  2   4  16   2]
#  [  8  64  32   8]
#  [  2  32 128   4]
#  [  4   8 512   2]]
# Episode Score: 5412
# Non valid move count: 120
# Valid move count: 379
# 50 episode running average: 3494.24
# Episode 94
# ............................[[  2   8   4  16]
#  [  4 512  32   2]
#  [  8  64   4 256]
#  [  2   4   2   8]]
# Episode Score: 6248
# Non valid move count: 265
# Valid move count: 413
# 50 episode running average: 3591.76
# Episode 95
# ......................[[  2  16  32   2]
#  [  8 128  64   8]
#  [ 16  64 256  16]
#  [  4  32   8   2]]
# Episode Score: 3520
# Non valid move count: 381
# Valid move count: 295
# 50 episode running average: 3597.2
# Episode 96
# .............[[  2   8   4   2]
#  [  8  16 128 256]
#  [ 16  32   4  64]
#  [  4  16   2   4]]
# Episode Score: 3092
# Non valid move count: 176
# Valid move count: 255
# 50 episode running average: 3597.36
# Episode 97
# ..................[[  4   2   8   2]
#  [  8  16 512   4]
#  [ 32 256  64  32]
#  [  2   8  16   2]]
# Episode Score: 6416
# Non valid move count: 109
# Valid move count: 433
# 50 episode running average: 3663.44
# Episode 98
# ...........[[  4   8  16   2]
#  [ 16  32 128  16]
#  [  8  64 256   4]
#  [  2  32   4   2]]
# Episode Score: 3216
# Non valid move count: 39
# Valid move count: 269
# 50 episode running average: 3664.96
# Episode 99
# .................

# %%
torch.save(policy_net.state_dict(), '/content/drive/MyDrive/2048_reinforcement_learning/policy_net.pth')
torch.save(target_net.state_dict(), '/content/drive/MyDrive/2048_reinforcement_learning/target_net.pth')

# %%
print(total_scores)
print(best_tile_list)

# %%
def sample_game_DQN():
  game = Board()
  state = encode_state(game.board).float()
  finish = False
  moved = True
  while not finish:
    if not moved:
      direction = np.random.randint(4)
    else:
      direction = select_action(state)
    #   direction = policy_net(state).max(1)[1].view(1, 1)

    moved = main_loop(game, direction)
    state = encode_state(game.board).float()

    if not moved:
      continue

    finish = game.is_game_over()
  total_score = game.total_score
  best_tile = game.board.max()
  # print("Game Over!, Total Score is {}".format(total_score))
  # print("Best tile: {}".format(best_tile))
  return total_score, best_tile

# %%
scores_DQN, best_tiles_DQN = [], []
for i in range(1000):
  if i % 10 == 0:
    print(f"Iteration {i}")
  total_score, best_tile = sample_game_DQN()
  scores_DQN.append(total_score)
  best_tiles_DQN.append(best_tile)
print("Finish")

# %%
print(scores_DQN)
print(best_tiles_DQN)
# Out:
# [6292, 5624, 1128, 3052, 1912, 3176, 2800, 1396, 4832, 3176, 1380, 5588, 5480, 652, 3044, 6092, 5136, 1392, 2196, 1768, 688, 3144, 1604, 1384, 4720, 3092, 4704, 1320, 6144, 1320, 4720, 5208, 888, 3676, 1000, 2380, 1172, 3076, 2396, 856, 5024, 2796, 1372, 2080, 2412, 2752, 4700, 3008, 1048, 3768, 1408, 3188, 3032, 4572, 848, 2664, 1688, 6992, 3136, 2984, 2364, 1388, 3172, 1124, 5100, 2860, 5248, 3508, 2780, 3612, 2084, 1356, 2776, 4660, 2824, 5436, 2416, 2456, 3360, 5588, 2728, 2024, 2288, 2144, 5928, 3080, 3944, 3188, 1584, 1308, 6732, 1708, 1912, 696, 6188, 3676, 1644, 2312, 6312, 3084, 608, 2996, 2268, 4688, 2612, 2332, 3196, 2780, 3028, 1820, 3080, 3160, 5264, 1188, 5936, 2128, 3084, 3348, 1476, 3392, 1688, 1520, 1564, 1568, 3008, 4660, 668, 3112, 2632, 3196, 2968, 1576, 1368, 2700, 5596, 624, 4336]
# [512, 512, 128, 256, 128, 256, 256, 128, 512, 256, 128, 512, 512, 64, 256, 512, 512, 128, 256, 128, 64, 256, 128, 128, 512, 256, 512, 128, 512, 128, 512, 512, 64, 256, 64, 256, 128, 256, 256, 64, 512, 256, 128, 128, 256, 256, 512, 256, 64, 256, 128, 256, 256, 512, 64, 256, 128, 512, 256, 256, 256, 128, 256, 128, 512, 256, 512, 256, 256, 256, 256, 128, 256, 512, 256, 512, 256, 256, 256, 512, 256, 256, 256, 128, 512, 256, 256, 256, 128, 128, 512, 128, 128, 64, 512, 256, 128, 256, 512, 256, 64, 256, 256, 512, 256, 256, 256, 256, 256, 128, 256, 256, 512, 128, 512, 128, 256, 256, 128, 256, 128, 128, 128, 128, 256, 512, 64, 256, 256, 256, 256, 128, 128, 256, 512, 64, 512]

# %%
# Plot best score distribution
plt.hist(scores_DQN, bins = 50)
plt.title("Total score distribution")
plt.xlabel("Total Score")
plt.ylabel("Frequency")
plt.show()

# %%
# Plot best score distribution
max_power = int(math.log(max(best_tiles_DQN), 2)) + 1
min_power = int(math.log(min(best_tiles_DQN), 2))
unique, counts = np.unique(best_tiles_DQN, return_counts=True)
plt.bar([str(2 ** i) for i in range(min_power, max_power)], counts)
plt.title("Best tile distribution")
plt.xlabel("Best tile")
plt.ylabel("Frequency")
plt.show()
